# %%
import json
import requests
import pandas as pd

def search_books(query):   
    # query string 문자열을 dict 선언
    payload = {
    'query':  query, #'파이썬',
    'display': 50,
    'sort': 'sim'
    }

    headers = {
        'X-Naver-Client-Id' : 'kZn6XBWktse9iSJKeOjD',
        'X-Naver-Client-Secret': 'qE7bDTTLM6'
    }

    url = 'https://openapi.naver.com/v1/search/book.json'
   
    # requests get(url, params, headers) 요청 
    res = requests.get(url, params=payload, headers=headers)
    # json() 함수로 응답 결과 가져오기
    items_data = res.json()['items'] 

    with open('books.json', 'w', encoding='utf-8') as f:
        json.dump(items_data, f, ensure_ascii=False, indent=4)

search_books('맥심')

df = pd.read_json('books.json')

df
# Out:
#                                                title  \
# 0                                     맥심문학 8 (삶의 향기)
# 1                                               곤줄박이
# 2                                          푸른 수염의 고래
# 3                                              꿈꾸는 손
# 4                                              꿈꾸는 손
# 5                독살에의 초대(엘리스피터스 추모소설) (엘리스 피터스 추모소설)
# 6                               맥심(MAXIM)(2022년 9월호)
# 7                            맥심(MAXIM) 정유나 태피스트리(B형)
# 8                        맥심(MAXIM) 박민정 A형(2023년 1월호)
# 9  [POD] 맥심 / 격언 : MAXIMS; Reflections or Sentenc...
#
#                                                 link  \
# 0  https://search.shopping.naver.com/book/catalog...
# 1  https://search.shopping.naver.com/book/catalog...
# 2  https://search.shopping.naver.com/book/catalog...
# 3  https://search.shopping.naver.com/book/catalog...
# 4  https://search.shopping.naver.com/book/catalog...
# 5  https://search.shopping.naver.com/book/catalog...
# 6  https://search.shopping.naver.com/book/catalog...
# 7  https://search.shopping.naver.com/book/catalog...
# 8  https://search.shopping.naver.com/book/catalog...
# 9  https://search.shopping.naver.com/book/catalog...
#
#                                                image     author  discount  \
# 0  https://shopping-phinf.pstatic.net/main_324971...        편집부     11700
# 1  https://shopping-phinf.pstatic.net/main_334346...      맥심문학회      9000
# 2  https://shopping-phinf.pstatic.net/main_334348...      맥심문학회      9000
# 3  https://shopping-phinf.pstatic.net/main_353027...      맥심문학회     23000
# 4  https://shopping-phinf.pstatic.net/main_353077...      맥심문학회     10800
# 5  https://shopping-phinf.pstatic.net/main_353033...  맥심 재커보우스키     16200
# 6  https://shopping-phinf.pstatic.net/main_343763...      MAXIM         0
# 7  https://shopping-phinf.pstatic.net/main_334356...      MAXIM         0
# 8  https://shopping-phinf.pstatic.net/main_369566...      MAXIM         0
# 9  https://shopping-phinf.pstatic.net/main_324581...     라 로시푸코     13600
#
#     publisher   pubdate           isbn  \
# 0       민들레향기  20120820  9788996819226
# 1       선우미디어  20081110  9788956582016
# 2       선우미디어  20061115  9788956581354
# 3          새미  20170108  9788956284057
# 4          새미  20030214  9788956280417
# 5        북하우스  20030210  9788956050492
# 6       와이미디어  20220825
# 7       와이미디어  20200828  8809653740026
# 8       와이미디어  20221222
# 9  부크크(bookk)  20190819  9791127280796
#
#                                          description
# 0  동서문학상 수상자들이 펴낸 맥심문학 동인지. 시인 정숙의 '구겨짐에 대하여', 정영...
# 1  [책을 내면서 중에서]\n우리들은 한걸음 나아가 일상에서 갈등하고 고민하던 일들을 ...
# 2  동서커피문학상에서 수상한 사람들의 모임, 맥심문학회의 문집, 제5집. 구성옥의 , ...
# 3  맥심문학회 회원들의 작품을 함께 엮은 책이다. 시, 수필, 소설 등이 수록되어 있으...
# 4  맥심문학회는 동서 커피문학상에서 수상한 사람들의 온라인 모임이다. 동서커피 문학상을...
# 5  중세 영국의 어두운 미로를 종횡무진 헤쳐가는 범죄스릴러 '캐드펠 시리즈'를 통해 일...
# 6
# 7  〈구성품〉\n\n-반유광 고급 실크 원단족자\n\n-벽걸이용 알루미늄 족자봉\n\n...
# 8
# 9  맥심 / 격언\n : MAXIMS; Reflections or Sentences a...
